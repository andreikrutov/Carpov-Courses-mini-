# %% [markdown]
# ### Мини-проект Carpov Courses

# %% [markdown]
# Описание данных
# Имеются следующие переменные:
#
# Hotel – тип отеля (City Hotel или Resort Hotel)
# Is canceled – бронирование было отменено (1) или нет (0); не отмененное считается успешным
# Lead time – количество дней, прошедших между датой бронирования и датой прибытия
# Arrival full date – полная дата прибытия
# Arrival date year – год прибытия
# Arrival date month – месяц прибытия
# Arrival date week number – номер недели прибытия
# Arrival date day of month – день прибытия
# Stays in weekend nights – количество выходных (суббота или воскресенье), которые гость забронировал для проживания в отеле
# Stays in week nights – количество дней (с понедельника по пятницу), которые гость забронировал для проживания в отеле
# Stays total nights – общее число забронированных ночей (сумма двух предыдущих колонок)
# Adults – число взрослых
# Children – число детей
# Babies – число младенцев
# Meal – выбранный тип питания
# Country – страна происхождения клиента
# Reserved room type – тип зарезервированного номера
# Assigned room type – тип полученного номера (может отличаться от забронированного)
# Customer type – тип бронирования
# Reservation status – значение последнего статуса брони: Canceled - было отменено клиентом; Check-Out - клиент    зарегистрировался, но уже покинул отель; No-Show - клиент не зарегистрировался и сообщил администрации отеля причину
# Reservation status date – дата обновления статуса

# %%
import pandas as pd

# %%
bookings = pd.read_csv('d://Carpov_Courses/projects/bookings/bookings.csv', sep=';')

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes.value_counts()
# Out:
# object     10
# int64      10
# float64     1
# dtype: int64

# %% [markdown]
# Меняем названия колонок. Приведем к нижнему регистру и уберем пробелы

# %%
cols = bookings.columns
cols = [x.lower() for x in cols]
cols = [x.replace(' ', '_') for x in cols]
cols
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_full_date',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'stays_total_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'reserved_room_type',
#  'assigned_room_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %%
bookings.columns = cols
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %% [markdown]
# Выбрать топ-5 стран, пользователи которых не отменяли бронирование (is_canceled = False)

# %%
bookings.query('is_canceled == 0') \
        .groupby('country', as_index=False) \
        .count() \
        .sort_values('hotel', ascending=False) \
        .head()
# Out:
#     country  hotel  is_canceled  lead_time  arrival_full_date  \
# 125     PRT  21071        21071      21071              21071
# 57      GBR   9676         9676       9676               9676
# 54      FRA   8481         8481       8481               8481
# 50      ESP   6391         6391       6391               6391
# 42      DEU   6069         6069       6069               6069
#
#      arrival_date_year  arrival_date_month  arrival_date_week_number  \
# 125              21071               21071                     21071
# 57                9676                9676                      9676
# 54                8481                8481                      8481
# 50                6391                6391                      6391
# 42                6069                6069                      6069
#
#      arrival_date_day_of_month  stays_in_weekend_nights  ...  \
# 125                      21071                    21071  ...
# ...

# %% [markdown]
#  На сколько ночей (stays_total_nights)  в среднем бронируют отели типа City Hotel? Resort Hotel? Запишите полученные значения в пропуски с точностью до 2 знаков после точки.

# %%
bookings.groupby('hotel', as_index=False) \
        .aggregate({'stays_total_nights': 'mean'})
# Out:
#           hotel  stays_total_nights
# 0    City Hotel            2.978142
# 1  Resort Hotel            4.318547

# %%
round(bookings.groupby('hotel', as_index=False) \
        .aggregate({'stays_total_nights': 'mean'})['stays_total_nights'],2)
# Out:
# 0    2.98
# 1    4.32
# Name: stays_total_nights, dtype: float64

# %% [markdown]
# Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга.
#
# Сколько подобных наблюдений встретилось в датасете?

# %%
bookings.query('assigned_room_type != reserved_room_type').count()[0]
# Out:
# 14917

# %% [markdown]
# Теперь проанализируйте даты запланированного прибытия (arrival_date_year).
#
# На какой месяц чаще всего оформляли бронь в 2016 году? Изменился ли самый популярный месяц в 2017?

# %%
bookings.query('arrival_date_year == 2016') \
                .groupby('arrival_date_month') \
                .count() \
                .sort_values('hotel', ascending =False)
# Out:
#                     hotel  is_canceled  lead_time  arrival_full_date  \
# arrival_date_month
# October              6203         6203       6203               6203
# May                  5478         5478       5478               5478
# April                5428         5428       5428               5428
# September            5394         5394       5394               5394
# June                 5292         5292       5292               5292
# August               5063         5063       5063               5063
# March                4824         4824       4824               4824
# July                 4572         4572       4572               4572
# November             4454         4454       4454               4454
# February             3891         3891       3891               3891
# December             3860         3860       3860               3860
# January              2248         2248       2248               2248
#
# ...

# %%
bookings.query('arrival_date_year == 2017') \
                .groupby('arrival_date_month') \
                .count() \
                .sort_values('hotel', ascending =False)
# Out:
#                     hotel  is_canceled  lead_time  arrival_full_date  \
# arrival_date_month
# May                  6313         6313       6313               6313
# April                5661         5661       5661               5661
# June                 5647         5647       5647               5647
# July                 5313         5313       5313               5313
# March                4970         4970       4970               4970
# August               4925         4925       4925               4925
# February             4177         4177       4177               4177
# January              3681         3681       3681               3681
#
#                     arrival_date_year  arrival_date_week_number  \
# arrival_date_month
# May                              6313                      6313
# April                            5661                      5661
# June                             5647                      5647
# ...

# %% [markdown]
# Сгруппируйте данные по годам, а затем проверьте, на какой месяц (arrival_date_month) бронирования отеля типа City Hotel отменялись чаще всего в 2015? 2016? 2017?

# %%
bookings.query('hotel == "City Hotel" & is_canceled == 1') \
        .groupby(['arrival_date_year', 'arrival_date_month'], as_index=False) \
        .count() \
        .sort_values('hotel', ascending=False)
# Out:
#     arrival_date_year arrival_date_month  hotel  is_canceled  lead_time  \
# 25               2017                May   2217         2217       2217
# 16               2016            October   1947         1947       1947
# 18               2017              April   1926         1926       1926
# 23               2017               June   1808         1808       1808
# 12               2016               June   1720         1720       1720
# 17               2016          September   1567         1567       1567
# 5                2015          September   1543         1543       1543
# 6                2016              April   1539         1539       1539
# 14               2016                May   1436         1436       1436
# 15               2016           November   1360         1360       1360
# 22               2017               July   1324         1324       1324
# 4                2015            October   1321         1321       1321
# ...

# %% [markdown]
# Посмотрите на числовые характеристики трёх колонок: adults, children и babies. Какая из них имеет наибольшее среднее значение?

# %%
bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# Создайте колонку total_kids, объединив столбцы children и babies. Для отелей какого типа среднее значение переменной оказалось наибольшим?

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.groupby('hotel', as_index=False).aggregate({'total_kids': 'mean'})
# Out:
#           hotel  total_kids
# 0    City Hotel    0.096311
# 1  Resort Hotel    0.142586

# %% [markdown]
# Не все бронирования завершились успешно (is_canceled), поэтому можно посчитать, сколько клиентов было потеряно в процессе.
# Churn rate (отток, коэффициент оттока) – это процент подписчиков (например, на push-уведомления от сайта), которые отписались от канала коммуникации, отказались от услуг сервиса в течение определенного периода времени. Иными словами, представляет собой отношение количества ушедших пользователей к общему количеству пользователей, выраженное в процентах.
#
# Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), в противном случае – False. Далее проверьте, среди какой группы пользователей показатель оттока выше.
#
# В качестве ответа укажите наибольший %, округленный до 2 знаков после точки (то есть доля 0.24563 будет 24.56% и в ответ пойдёт 24.56)

# %%
import numpy as np
bookings['has_kids'] = np.where(bookings['total_kids'] >=1 , True, False)

# %%
bookings.query('is_canceled == 1') \
        .groupby('has_kids',as_index=False) \
        .count()
# Out:
#    has_kids  hotel  is_canceled  lead_time  arrival_full_date  \
# 0     False  40965        40965      40965              40965
# 1      True   3259         3259       3259               3259
#
#    arrival_date_year  arrival_date_month  arrival_date_week_number  \
# 0              40965               40965                     40965
# 1               3259                3259                      3259
#
#    arrival_date_day_of_month  stays_in_weekend_nights  ...  children  babies  \
# 0                      40965                    40965  ...     40961   40965
# 1                       3259                     3259  ...      3259    3259
#
#     meal  country  reserved_room_type  assigned_room_type  customer_type  \
# 0  40965    40898               40965               40965          40965
# 1   3259     3259                3259                3259           3259
#
#    reservation_status  reservation_status_date  total_kids
# ...

# %%
churn_no_kids = bookings.query('is_canceled == 1') \
        .groupby('has_kids',as_index=False) \
        .count()['hotel'][0] / bookings.query('has_kids == False').shape[0]

churn_with_kids = bookings.query('is_canceled == 1') \
        .groupby('has_kids',as_index=False) \
        .count()['hotel'][1] / bookings.query('has_kids == True').shape[0]

# %%
print('Отток без детей: {}, Отток с детьми: {}'.format(round(churn_no_kids,4)*100, round(churn_with_kids, 4)*100))
# Out:
# Отток без детей: 37.22, Отток с детьми: 34.92
